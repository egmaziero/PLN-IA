# %% [markdown]
# # Word Overlap
# Simple way to measure lexical overlaping in two texts (sentence, paragraph or document).
# It removes punctuation and stopwords. Then, calculates the amount of common words over the sum of the words in two texts. So, this measure goes from 0 (different) to 0.5 (equal).

# %%
import nltk
import string

# %%
stopwords_list = nltk.corpus.stopwords.words('portuguese')

def tokenize_words(t):
    return nltk.tokenize.word_tokenize(t)

def remove_stopwords(tokens):
    return [t for t in tokens if t not in stopwords_list]

def remove_punctuation(t):
    return t.translate(str.maketrans('','',string.punctuation))

def word_overlap(t1, t2):
    tokens1 = remove_stopwords(tokenize_words(remove_punctuation(t1)))
    tokens2 = remove_stopwords(tokenize_words(remove_punctuation(t2)))
    matches = [1 for t in tokens1 if t in tokens2]
    return sum(matches) / (len(tokens1) + len(tokens2))

# %%
t1 = "Contagem manual de milhões de votos deixa 272 pessoas mortas e outras 1.878 doentes na Indonésia"
word_overlap(t1, t1)
# Out:
# 0.5

# %%
t2 = "Primeira eleição que juntou o voto presidencial com parlamentares nacionais e regionais num mesmo pleito."
word_overlap(t1, t2)
# Out:
# 0.0

# %%
t3 = "272 pessoas mortas e outras 1.878 doentes na Indonésia após contagem manual de milhões de votos."
word_overlap(t1, t3)
# Out:
# 0.4166666666666667

# %% [markdown]
# # Word2Vec
# download a pretrained wordembedding at http://www.nilc.icmc.usp.br/nilc/index.php/repositorio-de-word-embeddings-do-nilc
#
# You can click in the following link: http://143.107.183.175:22980/download.php?file=embeddings/word2vec/skip_s50.zip. Unzip the file inside notebooks directory

# %%
from gensim.models import KeyedVectors
model = KeyedVectors.load_word2vec_format('skip_s50.txt')

# %%
model.most_similar(positive = ['automóvel', 'carro'], negative = ['avião'])
# Out:
# /Users/erickmaziero/virtualenvs/NLP-IA_env/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('jipe', 0.7446665167808533),
#  ('supermercado', 0.7334405779838562),
#  ('porta-malas', 0.7268136143684387),
#  ('táxi', 0.723514974117279),
#  ('passeio', 0.7176169753074646),
#  ('chevette', 0.7145153880119324),
#  ('passageiro', 0.7145144939422607),
#  ('frigorífico', 0.7131503224372864),
#  ('quiosque', 0.7068798542022705),
#  ('alegórico', 0.7032663822174072)]

# %%
import scipy
import numpy as np
def cosine_distance_wordembedding_method(t1, t2):
    vector_1 = np.mean([model.get_vector(word) for word in t1.split() if word in model.vocab],axis=0)
    vector_2 = np.mean([model.get_vector(word) for word in t2.split() if word in model.vocab],axis=0)
    cosine = scipy.spatial.distance.cosine(vector_1, vector_2)
    print('Word Embedding method with a cosine distance asses that our two sentences are similar to',round((1-cosine)*100,2),'%')

cosine_distance_wordembedding_method(t1, t1)
cosine_distance_wordembedding_method(t1, t2)
cosine_distance_wordembedding_method(t2, t3)
# Out:
# Word Embedding method with a cosine distance asses that our two sentences are similar to 100.0 %
# Word Embedding method with a cosine distance asses that our two sentences are similar to 46.93 %
# Word Embedding method with a cosine distance asses that our two sentences are similar to 47.78 %

# %% [markdown]
# # Wordnets
# Do not forget to donwload: ```nltk.download()```

# %%
from nltk.corpus import wordnet

# %%
dog_synsets = wordnet.synsets('dog')
for i, dog in enumerate(dog_synsets):
    print('{} -> {}'.format(i, dog.definition()))
# Out:
# 0 -> a member of the genus Canis (probably descended from the common wolf) that has been domesticated by man since prehistoric times; occurs in many breeds
# 1 -> a dull unattractive unpleasant girl or woman
# 2 -> informal term for a man
# 3 -> someone who is morally reprehensible
# 4 -> a smooth-textured sausage of minced beef or pork usually smoked; often served on a bread roll
# 5 -> a hinged catch that fits into a notch of a ratchet to move a wheel forward or prevent it from moving backward
# 6 -> metal supports for logs in a fireplace
# 7 -> go after with the intent to catch

# %%
print(wordnet.synset('dog.n.01').lowest_common_hypernyms(wordnet.synset('cat.n.01')))
print(wordnet.synset('dog.n.01').lowest_common_hypernyms(wordnet.synset('duck.n.01')))
# Out:
# [Synset('carnivore.n.01')]
# [Synset('vertebrate.n.01')]

# %% [markdown]
# ### see http://www.nltk.org/howto/wordnet.html

# %%
dog = wordnet.synset('dog.n.01')
cat = wordnet.synset('cat.n.01')
car = wordnet.synset('car.n.01')

print('Path similarity')
print(dog.path_similarity(cat))
print(dog.path_similarity(car))
print()
print('Leacock-Chodorow similarity')
print(dog.lch_similarity(cat))
print(dog.lch_similarity(car))
print()
print('Wu-Palmer similarity')
print(dog.wup_similarity(cat))
print(dog.wup_similarity(car))
# Out:
# Path similarity
# 0.2
# 0.07692307692307693
#
# Leacock-Chodorow similarity
# 2.0281482472922856
# 1.072636802264849
#
# Wu-Palmer similarity
# 0.8571428571428571
# 0.4

# %%
from itertools import islice
for synset in islice(wordnet.all_synsets('n'), 10):
    print(synset, synset.hypernyms())
# Out:
# Synset('entity.n.01') []
# Synset('physical_entity.n.01') [Synset('entity.n.01')]
# Synset('abstraction.n.06') [Synset('entity.n.01')]
# Synset('thing.n.12') [Synset('physical_entity.n.01')]
# Synset('object.n.01') [Synset('physical_entity.n.01')]
# Synset('whole.n.02') [Synset('object.n.01')]
# Synset('congener.n.03') [Synset('whole.n.02')]
# Synset('living_thing.n.01') [Synset('whole.n.02')]
# Synset('organism.n.01') [Synset('living_thing.n.01')]
# Synset('benthos.n.02') [Synset('organism.n.01')]

# %% [markdown]
# # Portuguese usage

# %%
carro = wordnet.synsets('carro', lang='por')
print(carro)
# here a Word Sense Disambiguation tool is needed!

hyper = carro[1].hypernyms()[0]
print(hyper)
print(hyper.lemma_names(lang='por'))
hyper_hyper = hyper.hypernyms()[0]

print(hyper_hyper)
print(hyper_hyper.lemma_names(lang='por'))

hyper_hyper_hyper = hyper_hyper.hypernyms()[0]
print(hyper_hyper_hyper)
print(hyper_hyper_hyper.lemma_names(lang='por'))
# Out:
# [Synset('beach_wagon.n.01'), Synset('car.n.01'), Synset('car.n.02'), Synset('cart.n.01')]
# Synset('motor_vehicle.n.01')
# ['veículos_motorizados']
# Synset('self-propelled_vehicle.n.01')
# []
# Synset('wheeled_vehicle.n.01')
# []

# %% [markdown]
# # Synsets
# Download synset database from http://www.nilc.icmc.usp.br/tep2/download.htm
# The file ```base_tep2.txt``` follows the format:
#
# Numero_sequencial do synset. \[nome_da_categoria_do_synset\] {Conjunto Synset separado por virgulas} <numero_identificador do(s) Synset(s) antonimo(s)>

# %%
import re

synsets = {}
with open('base_tep2/base_tep2.txt', 'r', encoding='latin1') as tep_file:
    for line in tep_file.readlines():
        syn_id = re.match('^(?P<int>\d+)', line).group('int')
        cat = re.search('\[(?P<cat>(.*?))\]', line).group('cat')
        syn = re.search('\{(?P<syn>(.*?))\}', line).group('syn')
        s = re.search('\<(?P<ant>(.*?))\>', line)
        ant = None
        if s is not None:
            ant = s.group('ant')
        synsets[syn_id] = {'words': [w.strip() for w in syn.split(',')],
                           'category': cat,
                           'antonym': ant}

# %%
synsets
# Out:
# {'1': {'words': ['exagerar',
#    'exceder',
#    'quinta-essenciar',
#    'rebuscar',
#    'refinar',
#    'requintar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '2': {'words': ['ababalhar', 'babar', 'escumar', 'espumar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '3': {'words': ['ababalhar', 'sujar'], 'category': 'Verbo', 'antonym': None},
#  '4': {'words': ['aclarar', 'alumiar', 'clarear', 'iluminar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '5': {'words': ['enegrecer', 'escurecer'],
#   'category': 'Verbo',
#   'antonym': '4'},
#  '6': {'words': ['limpar', 'purgar', 'purificar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '7': {'words': ['impurificar', 'sujar'], 'category': 'Verbo', 'antonym': '6'},
#  '8': {'words': ['apurar', 'clarificar', 'limpar', 'purgar', 'purificar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '9': {'words': ['purgar'], 'category': 'Verbo', 'antonym': '7'},
#  '10': {'words': ['coar', 'destilar', 'insinuar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '11': {'words': ['animar'], 'category': 'Verbo', 'antonym': '1746'},
#  '12': {'words': ['açalmar', 'fornecer-se', 'prover-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '13': {'words': ['acamaradar', 'amigar', 'amistar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '14': {'words': ['embarricar', 'embarrilar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '15': {'words': ['bastar', 'satisfazer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '16': {'words': ['depravar-se'], 'category': 'Verbo', 'antonym': None},
#  '17': {'words': ['armar-se', 'munir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '18': {'words': ['abceder', 'absceder', 'aporismar', 'supurar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '19': {'words': ['abecar', 'abotoar', 'abufelar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '20': {'words': ['abençoar-se', 'benzer-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '21': {'words': ['conformar-se', 'sujeitar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '22': {'words': ['abater-se', 'acamar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '23': {'words': ['abater', 'acamar'], 'category': 'Verbo', 'antonym': None},
#  '24': {'words': ['abalar', 'destruir', 'gastar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '25': {'words': ['esconder', 'fingir'], 'category': 'Verbo', 'antonym': None},
#  '26': {'words': ['disfarçar-se', 'esconder-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '27': {'words': ['calar', 'esconder', 'guardar'],
#   'category': 'Verbo',
#   'antonym': '3716'},
#  '28': {'words': ['absolver', 'desculpar', 'inocentar', 'isentar', 'perdoar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '29': {'words': ['culpar-se'], 'category': 'Verbo', 'antonym': '2624'},
#  '30': {'words': ['concordar', 'harmonizar'],
#   'category': 'Verbo',
#   'antonym': '1854'},
#  '31': {'words': ['apaixonar', 'arrebatar', 'enlevar', 'entusiasmar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '32': {'words': ['privar'], 'category': 'Verbo', 'antonym': None},
#  '33': {'words': ['manter-se', 'sustentar-se', 'suster-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '34': {'words': ['opor-se'], 'category': 'Verbo', 'antonym': None},
#  '35': {'words': ['apagar'], 'category': 'Verbo', 'antonym': None},
#  '36': {'words': ['abusar', 'exorbitar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '37': {'words': ['abusar', 'enganar', 'prevaricar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '38': {'words': ['abusar', 'anarquizar', 'desmoralizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '39': {'words': ['alentar-se', 'animar-se'],
#   'category': 'Verbo',
#   'antonym': '2644'},
#  '40': {'words': ['abaixar', 'acocorar', 'agachar'],
#   'category': 'Verbo',
#   'antonym': '221'},
#  '41': {'words': ['ceder'], 'category': 'Verbo', 'antonym': None},
#  '42': {'words': ['acaboclar-se',
#    'acaiçarar-se',
#    'acaipirar-se',
#    'amatutar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '43': {'words': ['abeirar-se', 'aproximar-se', 'beirar'],
#   'category': 'Verbo',
#   'antonym': '1104'},
#  '44': {'words': ['acalentar', 'aconchegar', 'aninhar', 'conchegar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '45': {'words': ['acalentar-se'], 'category': 'Verbo', 'antonym': None},
#  '46': {'words': ['enobrecer', 'enricar', 'enriquecer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '47': {'words': ['abandalhar', 'enxovalhar', 'sujar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '48': {'words': ['avelhentar'], 'category': 'Verbo', 'antonym': None},
#  '49': {'words': ['considerar', 'estimar', 'prezar'],
#   'category': 'Verbo',
#   'antonym': '3436'},
#  '50': {'words': ['destrançar'], 'category': 'Verbo', 'antonym': '1879'},
#  '51': {'words': ['entremostrar', 'esboçar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '52': {'words': ['acanhar', 'embaraçar', 'tolher'],
#   'category': 'Verbo',
#   'antonym': None},
#  '53': {'words': ['abraçar-se', 'apertar-se', 'cingir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '54': {'words': ['avergonhar', 'avexar', 'envergonhar', 'vexar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '55': {'words': ['escravizar', 'esmagar', 'oprimir', 'tiranizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '56': {'words': ['proibir', 'proscrever'],
#   'category': 'Verbo',
#   'antonym': None},
#  '57': {'words': ['paralisar', 'tolher'],
#   'category': 'Verbo',
#   'antonym': None},
#  '58': {'words': ['autorizar', 'permitir'],
#   'category': 'Verbo',
#   'antonym': '1086'},
#  '59': {'words': ['apor', 'juntar', 'justapor'],
#   'category': 'Verbo',
#   'antonym': '1446'},
#  '60': {'words': ['unir-se'], 'category': 'Verbo', 'antonym': '2829'},
#  '61': {'words': ['defrontar-se', 'deparar-se', 'encontrar-se', 'topar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '62': {'words': ['confrontar-se', 'defrontar-se', 'enfrentar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '63': {'words': ['maltratar'], 'category': 'Verbo', 'antonym': '3679'},
#  '64': {'words': ['acelerar',
#    'adiantar',
#    'apressar',
#    'estugar',
#    'picar',
#    'precipitar'],
#   'category': 'Verbo',
#   'antonym': '3727'},
#  '65': {'words': ['abrigar-se', 'acoitar-se', 'acolher-se', 'asilar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '66': {'words': ['agüentar-se', 'conservar-se', 'conter-se', 'manter-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '67': {'words': ['apanhar', 'guardar', 'recolher'],
#   'category': 'Verbo',
#   'antonym': None},
#  '68': {'words': ['encolher-se', 'encurtar-se'],
#   'category': 'Verbo',
#   'antonym': '2033'},
#  '69': {'words': ['alongar-se', 'estender-se', 'estirar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '70': {'words': ['dobrar-se', 'enrolar-se'],
#   'category': 'Verbo',
#   'antonym': '1369'},
#  '71': {'words': ['distender', 'espalhar', 'estender'],
#   'category': 'Verbo',
#   'antonym': None},
#  '72': {'words': ['alargar', 'larguear'],
#   'category': 'Verbo',
#   'antonym': '3462'},
#  '73': {'words': ['alquebrar',
#    'aquebrantar',
#    'cansar',
#    'debilitar',
#    'deprimir',
#    'derrear',
#    'enfraquecer',
#    'extenuar',
#    'prostrar',
#    'quebrantar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '74': {'words': ['acurvar', 'alquebrar', 'curvar', 'prostrar', 'vergar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '75': {'words': ['abaixar', 'baixar'],
#   'category': 'Verbo',
#   'antonym': '3301'},
#  '76': {'words': ['acrescentar', 'aumentar', 'elevar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '77': {'words': ['altear',
#    'aumentar',
#    'avantajar',
#    'avultar',
#    'crescer',
#    'subir'],
#   'category': 'Verbo',
#   'antonym': '3467'},
#  '78': {'words': ['elevar', 'promover'], 'category': 'Verbo', 'antonym': None},
#  '79': {'words': ['erguer', 'sobrelevar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '80': {'words': ['alevantar-se',
#    'levantar-se',
#    'reabilitar-se',
#    'reerguer-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '81': {'words': ['alvitrar',
#    'aventar',
#    'lembrar',
#    'levantar',
#    'propor',
#    'sugerir',
#    'suscitar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '82': {'words': ['recolher', 'retirar', 'sacar', 'tirar', 'tomar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '83': {'words': ['encerrar', 'terminar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '84': {'words': ['alevantar-se', 'desencadear-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '85': {'words': ['acrescentar',
#    'agigantar',
#    'ampliar',
#    'aumentar',
#    'avultar',
#    'engordar',
#    'engrandecer'],
#   'category': 'Verbo',
#   'antonym': '3469'},
#  '86': {'words': ['ascender', 'avultar', 'chegar', 'montar', 'subir'],
#   'category': 'Verbo',
#   'antonym': '3120'},
#  '87': {'words': ['arborizar'], 'category': 'Verbo', 'antonym': '1482'},
#  '88': {'words': ['alevantar-se', 'hastear-se', 'içar-se', 'levantar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '89': {'words': ['desfraldar-se', 'hastear-se', 'içar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '90': {'words': ['baratinar-se',
#    'desacomodar-se',
#    'desarranjar-se',
#    'perturbar-se',
#    'transtornar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '91': {'words': ['alterar', 'desarranjar', 'embaraçar', 'estorvar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '92': {'words': ['afobar-se',
#    'atarantar-se',
#    'atrapalhar-se',
#    'perturbar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '93': {'words': ['adulterar-se',
#    'alterar-se',
#    'contrafazer-se',
#    'falsificar-se',
#    'sofisticar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '94': {'words': ['contrafazer-se', 'reprimir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '95': {'words': ['falsificar'], 'category': 'Verbo', 'antonym': None},
#  '96': {'words': ['arguciar', 'sofismar', 'sofisticar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '97': {'words': ['desviar', 'mudar'], 'category': 'Verbo', 'antonym': None},
#  '98': {'words': ['discrepar', 'variar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '99': {'words': ['desestimular', 'desmotivar'],
#   'category': 'Verbo',
#   'antonym': '4077'},
#  '100': {'words': ['animar', 'estimular', 'incentivar'],
#   'category': 'Verbo',
#   'antonym': '3015'},
#  '101': {'words': ['afear',
#    'afeiar',
#    'desfear',
#    'desfigurar',
#    'deturpar',
#    'enfear'],
#   'category': 'Verbo',
#   'antonym': '102'},
#  '102': {'words': ['embelezar'], 'category': 'Verbo', 'antonym': '101'},
#  '103': {'words': ['argumentar', 'concluir', 'deduzir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '104': {'words': ['alegar', 'argüir', 'argumentar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '105': {'words': ['alugar', 'locar'], 'category': 'Verbo', 'antonym': None},
#  '106': {'words': ['arrepiar',
#    'arrupiar',
#    'estremecer',
#    'horripilar',
#    'horrorizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '107': {'words': ['manear', 'manejar', 'manusear', 'menear', 'tratar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '108': {'words': ['arrecear', 'recear', 'respeitar', 'temer', 'tremer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '109': {'words': ['arrecear',
#    'arrecear-se',
#    'recear-se',
#    'temer-se',
#    'tremer-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '110': {'words': ['aclarar-se',
#    'alumbrar-se',
#    'alumiar-se',
#    'esclarecer-se',
#    'iluminar-se'],
#   'category': 'Verbo',
#   'antonym': '3602'},
#  '111': {'words': ['alvejar', 'mirar'], 'category': 'Verbo', 'antonym': None},
#  '112': {'words': ['alvejar', 'atingir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '113': {'words': ['adormecer',
#    'arrefecer',
#    'arrefentar',
#    'esfriar',
#    'refecer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '114': {'words': ['adotar', 'eleger', 'escolher', 'preferir', 'tomar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '115': {'words': ['adotar', 'aprovar', 'outorgar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '116': {'words': ['aceitar',
#    'admitir',
#    'adotar',
#    'receber',
#    'reconhecer',
#    'tomar'],
#   'category': 'Verbo',
#   'antonym': '2733'},
#  '117': {'words': ['apreender', 'capturar', 'tomar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '118': {'words': ['apreender', 'conquistar', 'tomar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '119': {'words': ['empregar', 'gastar', 'tomar', 'usar', 'utilizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '120': {'words': ['comer', 'tomar'], 'category': 'Verbo', 'antonym': None},
#  '121': {'words': ['seguir', 'tomar'], 'category': 'Verbo', 'antonym': None},
#  '122': {'words': ['avaliar', 'calcular', 'medir', 'tomar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '123': {'words': ['abraçar-se', 'juntar-se', 'unir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '124': {'words': ['anteceder', 'antepassar', 'preceder'],
#   'category': 'Verbo',
#   'antonym': '2490'},
#  '125': {'words': ['conceder',
#    'deixar',
#    'facilitar',
#    'facultar',
#    'outorgar',
#    'permitir',
#    'possibilitar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '126': {'words': ['confessar-se', 'outorgar-se', 'reconhecer-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '127': {'words': ['aforar-se',
#    'apropriar-se',
#    'arrogar-se',
#    'atribuir-se',
#    'avocar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '128': {'words': ['admitir', 'consentir', 'permitir', 'tolerar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '129': {'words': ['abonar', 'acreditar', 'afiançar', 'creditar', 'garantir'],
#   'category': 'Verbo',
#   'antonym': '1466'},
#  '130': {'words': ['abonar', 'aprovar', 'confirmar'],
#   'category': 'Verbo',
#   'antonym': '3127'},
#  '131': {'words': ['abonar', 'qualificar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '132': {'words': ['abonar-se', 'gabar-se', 'orgulhar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '133': {'words': ['abonar-se', 'apadrinhar-se', 'autorizar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '134': {'words': ['acusar', 'confessar', 'declarar', 'revelar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '135': {'words': ['admitir', 'confessar', 'declarar', 'reconhecer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '136': {'words': ['confessar-se', 'declarar-se', 'reconhecer-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '137': {'words': ['examinar', 'explorar', 'observar', 'reconhecer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '138': {'words': ['informar', 'instruir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '139': {'words': ['adscrever-se',
#    'adstringir-se',
#    'limitar-se',
#    'reduzir-se',
#    'restringir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '140': {'words': ['desviar', 'forçar', 'torcer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '141': {'words': ['atrair', 'converter', 'reduzir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '142': {'words': ['acondimentar',
#    'adubar',
#    'assazoar',
#    'assazonar',
#    'condimentar',
#    'sazonar',
#    'temperar'],
#   'category': 'Verbo',
#   'antonym': '1539'},
#  '143': {'words': ['adubar', 'estercar', 'estrumar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '144': {'words': ['defumar',
#    'incensar',
#    'perfumar',
#    'turibular',
#    'turiferar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '145': {'words': ['adunar', 'subordinar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '146': {'words': ['ardejar', 'arder', 'escaldar', 'queimar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '147': {'words': ['fundir-se', 'queimar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '148': {'words': ['atirar', 'disparar', 'queimar', 'tirar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '149': {'words': ['amelindrar-se',
#    'irritar-se',
#    'melindrar-se',
#    'queimar-se',
#    'zangar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '150': {'words': ['acirrar-se', 'esquentar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '151': {'words': ['aviltar-se', 'rebaixar-se'],
#   'category': 'Verbo',
#   'antonym': '3641'},
#  '152': {'words': ['desajustar', 'desregular'],
#   'category': 'Verbo',
#   'antonym': '3246'},
#  '153': {'words': ['acomodar-se', 'ajustar-se', 'chegar-se', 'conformar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '154': {'words': ['comerciar', 'contratar', 'negociar', 'tratar'],
#   'category': 'Verbo',
#   'antonym': '1487'},
#  '155': {'words': ['calhar', 'encaixar', 'encaixar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '156': {'words': ['bater', 'coincidir', 'combinar', 'concordar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '157': {'words': ['inscrever-se', 'matricular-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '158': {'words': ['assentar', 'sentar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '159': {'words': ['abancar-se', 'assentar-se', 'sentar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '160': {'words': ['assentar', 'determinar', 'estipular', 'marcar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '161': {'words': ['ajustar-se', 'assentar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '162': {'words': ['adstringir', 'subjugar', 'submeter'],
#   'category': 'Verbo',
#   'antonym': None},
#  '163': {'words': ['adverbar', 'anotar', 'averbar', 'registar', 'registrar'],
#   'category': 'Verbo',
#   'antonym': '1187'},
#  '164': {'words': ['apoiar', 'defender', 'propugnar'],
#   'category': 'Verbo',
#   'antonym': '3638'},
#  '165': {'words': ['agitar-se', 'bater-se', 'combater-se', 'debater-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '166': {'words': ['admoestar', 'advertir', 'amoestar', 'avisar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '167': {'words': ['apetitar',
#    'apimentar',
#    'atentar',
#    'estimular',
#    'excitar',
#    'tentar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '168': {'words': ['atender', 'considerar', 'examinar', 'observar'],
#   'category': 'Verbo',
#   'antonym': '1240'},
#  '169': {'words': ['minutar', 'notar', 'rascunhar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '170': {'words': ['cronometrar', 'minutar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '171': {'words': ['estranhar', 'notar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '172': {'words': ['espiar-se', 'observar-se', 'vigiar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '173': {'words': ['observar', 'olhar', 'reparar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '174': {'words': ['assistir',
#    'presenciar',
#    'testemunhar',
#    'ver',
#    'verificar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '175': {'words': ['conhecer', 'ver'], 'category': 'Verbo', 'antonym': None},
#  '176': {'words': ['ler', 'ver'], 'category': 'Verbo', 'antonym': None},
#  '177': {'words': ['assistir', 'examinar', 'ver'],
#   'category': 'Verbo',
#   'antonym': None},
#  '178': {'words': ['conviver', 'freqüentar', 'versar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '179': {'words': ['compreender-se',
#    'entender-se',
#    'perceber-se',
#    'reconhecer-se',
#    'ver-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '180': {'words': ['amparar', 'auxiliar', 'defender', 'proteger', 'socorrer'],
#   'category': 'Verbo',
#   'antonym': '1108'},
#  '181': {'words': ['acautelar-se',
#    'adargar-se',
#    'afortalezar-se',
#    'anteparar-se',
#    'defender-se',
#    'proteger-se',
#    'refugiar-se',
#    'resguardar-se',
#    'velar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '182': {'words': ['apetrechar-se',
#    'armar-se',
#    'equipar-se',
#    'petrechar-se',
#    'premunir-se',
#    'preparar-se',
#    'prover-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '183': {'words': ['preparar', 'prevenir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '184': {'words': ['dispor', 'influenciar', 'prevenir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '185': {'words': ['advogar', 'interceder'],
#   'category': 'Verbo',
#   'antonym': None},
#  '186': {'words': ['defender-se', 'resistir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '187': {'words': ['edificar', 'instruir', 'sustentar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '188': {'words': ['desnutrir-se'], 'category': 'Verbo', 'antonym': '2183'},
#  '189': {'words': ['adminicular', 'ajudar', 'auxiliar', 'sustentar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '190': {'words': ['afaimar', 'afomear', 'esfaimar', 'esfomear'],
#   'category': 'Verbo',
#   'antonym': '2519'},
#  '191': {'words': ['aclamar-se', 'eleger-se', 'proclamar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '192': {'words': ['afamar', 'celebrizar', 'notabilizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '193': {'words': ['afamilhar-se', 'afamiliar-se', 'casar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '194': {'words': ['afainar-se', 'afanar-se', 'azafamar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '195': {'words': ['arrebatar', 'raptar', 'roubar', 'seqüestrar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '196': {'words': ['esquivar-se', 'furtar-se', 'roubar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '197': {'words': ['laborar', 'labutar', 'levar', 'suportar', 'viver'],
#   'category': 'Verbo',
#   'antonym': None},
#  '198': {'words': ['academiar', 'academicizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '199': {'words': ['acarrear', 'acarretar', 'carrear'],
#   'category': 'Verbo',
#   'antonym': None},
#  '200': {'words': ['ocasionar-se', 'originar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '201': {'words': ['acumular-se', 'ajuntar-se', 'amontoar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '202': {'words': ['acrescentar-se',
#    'acrescer-se',
#    'adicionar-se',
#    'ajuntar-se',
#    'aumentar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '203': {'words': ['cumprir', 'preencher', 'realizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '204': {'words': ['completar', 'cumprir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '205': {'words': ['acondicionar', 'arrecadar', 'guardar', 'preservar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '206': {'words': ['conservar', 'guardar', 'manter', 'reter', 'segurar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '207': {'words': ['cumprir', 'guardar', 'praticar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '208': {'words': ['abster-se', 'guardar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '209': {'words': ['esperar', 'guardar-se', 'reservar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '210': {'words': ['deixar', 'poupar', 'respeitar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '211': {'words': ['admitir', 'aturar', 'respeitar', 'suportar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '212': {'words': ['obedecer', 'render-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '213': {'words': ['acavalar-se', 'amontoar-se', 'sobrepor-se', 'superpor-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '214': {'words': ['acerar', 'avigorar', 'azeirar', 'azerar', 'robustecer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '215': {'words': ['aceder', 'conformar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '216': {'words': ['adicionar', 'somar'],
#   'category': 'Verbo',
#   'antonym': '3466'},
#  '217': {'words': ['somar', 'totalizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '218': {'words': ['aprovar', 'assentir', 'permitir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '219': {'words': ['intransigir'], 'category': 'Verbo', 'antonym': '3657'},
#  '220': {'words': ['abaixar', 'baixar', 'descer', 'pender'],
#   'category': 'Verbo',
#   'antonym': '221'},
#  '221': {'words': ['alevantar'], 'category': 'Verbo', 'antonym': '220'},
#  '222': {'words': ['desigualar', 'desnivelar'],
#   'category': 'Verbo',
#   'antonym': '3275'},
#  '223': {'words': ['abaixar', 'encaminhar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '224': {'words': ['decair', 'descer'], 'category': 'Verbo', 'antonym': None},
#  '225': {'words': ['apanhar', 'embarcar', 'pegar', 'tomar'],
#   'category': 'Verbo',
#   'antonym': '2532'},
#  '226': {'words': ['abaixar', 'baixar', 'baixar-se', 'descer'],
#   'category': 'Verbo',
#   'antonym': '221'},
#  '227': {'words': ['abaixar-se', 'baixar-se', 'inclinar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '228': {'words': ['encaminhar', 'endereçar', 'enviar', 'estradear'],
#   'category': 'Verbo',
#   'antonym': None},
#  '229': {'words': ['abalar-se', 'ceder', 'mover-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '230': {'words': ['aceitar'], 'category': 'Verbo', 'antonym': '2734'},
#  '231': {'words': ['estimar-se', 'prezar-se'],
#   'category': 'Verbo',
#   'antonym': '1521'},
#  '232': {'words': ['digerir', 'gastar'], 'category': 'Verbo', 'antonym': None},
#  '233': {'words': ['agitar', 'propor', 'suscitar', 'ventilar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '234': {'words': ['ocupar-se', 'preocupar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '235': {'words': ['abalar-se', 'demover-se', 'dispor-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '236': {'words': ['assaltar', 'assaltear', 'assediar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '237': {'words': ['atacar', 'iniciar'], 'category': 'Verbo', 'antonym': None},
#  '238': {'words': ['acusar', 'agredir', 'atacar', 'hostilizar'],
#   'category': 'Verbo',
#   'antonym': '361'},
#  '239': {'words': ['agredir', 'atacar'],
#   'category': 'Verbo',
#   'antonym': '1955'},
#  '240': {'words': ['adiantar-se', 'andar', 'avançar', 'mover-se'],
#   'category': 'Verbo',
#   'antonym': '1144'},
#  '241': {'words': ['apropriar-se', 'avançar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '242': {'words': ['adiantar-se', 'avançar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '243': {'words': ['empossar-se', 'investir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '244': {'words': ['empossar', 'investir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '245': {'words': ['afastar-se', 'arredar', 'arredar-se', 'recuar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '246': {'words': ['ferrar', 'ferretear', 'marcar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '247': {'words': ['aprazar', 'assinar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '248': {'words': ['abalofar-se', 'afofar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '249': {'words': ['abalroar-se',
#    'balroar-se',
#    'chocar-se',
#    'colidir-se',
#    'embater-se',
#    'encontrar-se',
#    'tocar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '250': {'words': ['embater-se', 'esbarrar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '251': {'words': ['abanar', 'abanicar', 'refrescar', 'ventilar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '252': {'words': ['abanar-se', 'abanicar-se', 'refrescar-se', 'ventilar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '253': {'words': ['mover', 'saracotear'],
#   'category': 'Verbo',
#   'antonym': None},
#  '254': {'words': ['abandonar', 'abjurar', 'abnegar', 'desistir', 'renunciar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '255': {'words': ['abandonar', 'deixar', 'entregar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '256': {'words': ['abandonar-se', 'entregar-se', 'render-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '257': {'words': ['abjurar',
#    'apostasiar',
#    'apostatar',
#    'arrenegar',
#    'perjurar',
#    'renegar',
#    'renunciar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '258': {'words': ['desertar', 'fugir', 'retirar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '259': {'words': ['deixar', 'pospor'], 'category': 'Verbo', 'antonym': None},
#  '260': {'words': ['dar', 'deixar', 'produzir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '261': {'words': ['constituir', 'deixar', 'instituir', 'nomear'],
#   'category': 'Verbo',
#   'antonym': None},
#  '262': {'words': ['deixar', 'separar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '263': {'words': ['consentir', 'deixar', 'permitir'],
#   'category': 'Verbo',
#   'antonym': '973'},
#  '264': {'words': ['deixar', 'esperar'], 'category': 'Verbo', 'antonym': None},
#  '265': {'words': ['largar', 'retirar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '266': {'words': ['cassar', 'privar', 'retirar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '267': {'words': ['arrear', 'mobilhar', 'mobiliar'],
#   'category': 'Verbo',
#   'antonym': '1479'},
#  '268': {'words': ['largar', 'libertar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '269': {'words': ['atorar', 'ir-se', 'largar', 'partir', 'torar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '270': {'words': ['impelir', 'lançar', 'largar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '271': {'words': ['deitar-se', 'largar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '272': {'words': ['abarbar'], 'category': 'Verbo', 'antonym': None},
#  '273': {'words': ['abarbar', 'sobrecarregar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '274': {'words': ['abastonar-se',
#    'apoiar-se',
#    'arrimar-se',
#    'escorar-se',
#    'firmar-se'],
#   'category': 'Verbo',
#   'antonym': '1171'},
#  '275': {'words': ['espionar', 'sondar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '276': {'words': ['abemolar-se',
#    'adamar-se',
#    'adengar-se',
#    'adocicar-se',
#    'afetar-se',
#    'amulherar-se',
#    'amulherengar-se',
#    'efeminar-se',
#    'efeminizar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '277': {'words': ['abestalhar-se', 'bestificar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '278': {'words': ['argamassar'], 'category': 'Verbo', 'antonym': None},
#  '279': {'words': ['cimentar-se', 'consolidar-se', 'firmar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '280': {'words': ['abafar', 'afogar', 'asfixiar', 'sufocar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '281': {'words': ['restabelecer', 'restaurar', 'validar'],
#   'category': 'Verbo',
#   'antonym': '2635'},
#  '282': {'words': ['repatriar'], 'category': 'Verbo', 'antonym': '3356'},
#  '283': {'words': ['ablocar', 'alugar', 'arrendar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '284': {'words': ['arrendar', 'rendar', 'rendilhar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '285': {'words': ['cobiçar', 'devorar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '286': {'words': ['deglutir', 'engolir', 'ingerir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '287': {'words': ['acreditar', 'engolir', 'tragar'],
#   'category': 'Verbo',
#   'antonym': '860'},
#  '288': {'words': ['expirar'], 'category': 'Verbo', 'antonym': '403'},
#  '289': {'words': ['desacreditar-se', 'difamar-se', 'infamar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '290': {'words': ['boiar', 'comer'], 'category': 'Verbo', 'antonym': None},
#  '291': {'words': ['abolachar', 'aboleimar', 'achatar', 'apalmar', 'espalmar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '292': {'words': ['eliminar-se', 'matar-se', 'suicidar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '293': {'words': ['condenar', 'proscrever', 'sentenciar'],
#   'category': 'Verbo',
#   'antonym': '28'},
#  '294': {'words': ['desinchar-se', 'esvaziar-se'],
#   'category': 'Verbo',
#   'antonym': '3633'},
#  '295': {'words': ['amar', 'copular'], 'category': 'Verbo', 'antonym': None},
#  '296': {'words': ['refluir', 'vazar'], 'category': 'Verbo', 'antonym': None},
#  '297': {'words': ['retirar-se', 'sair', 'vazar'],
#   'category': 'Verbo',
#   'antonym': '3753'},
#  '298': {'words': ['arrancar', 'vazar'], 'category': 'Verbo', 'antonym': None},
#  '299': {'words': ['abordar', 'tratar', 'versar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '300': {'words': ['curar', 'medicar', 'tratar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '301': {'words': ['cuidar-se', 'medicar-se', 'tratar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '302': {'words': ['desnutrir'], 'category': 'Verbo', 'antonym': '2429'},
#  '303': {'words': ['praticar', 'tratar', 'usar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '304': {'words': ['alcunhar', 'chamar', 'tratar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '305': {'words': ['compulsar', 'estudar', 'versar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '306': {'words': ['considerar', 'pesar', 'ponderar', 'versar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '307': {'words': ['abrancar', 'embrancar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '308': {'words': ['excluir'], 'category': 'Verbo', 'antonym': '3118'},
#  '309': {'words': ['abranger-se',
#    'compreender-se',
#    'encerrar-se',
#    'incluir-se'],
#   'category': 'Verbo',
#   'antonym': '723'},
#  '310': {'words': ['alongar', 'prolongar'],
#   'category': 'Verbo',
#   'antonym': '3464'},
#  '311': {'words': ['desajustar-se'], 'category': 'Verbo', 'antonym': '4060'},
#  '312': {'words': ['arranjar-se', 'ataviar-se', 'preparar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '313': {'words': ['arrumar', 'estivar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '314': {'words': ['desabituar-se', 'desacostumar-se'],
#   'category': 'Verbo',
#   'antonym': '3039'},
#  '315': {'words': ['aconchegar', 'ajeitar', 'compor', 'conchegar'],
#   'category': 'Verbo',
#   'antonym': '316'},
#  '316': {'words': ['desajeitar', 'descompor'],
#   'category': 'Verbo',
#   'antonym': '315'},
#  '317': {'words': ['acondicionar', 'condicionar', 'regular'],
#   'category': 'Verbo',
#   'antonym': None},
#  '318': {'words': ['desapropriar-se'], 'category': 'Verbo', 'antonym': '2507'},
#  '319': {'words': ['desacelerar'], 'category': 'Verbo', 'antonym': '3128'},
#  '320': {'words': ['esquivar', 'eximir', 'poupar', 'subtrair'],
#   'category': 'Verbo',
#   'antonym': None},
#  '321': {'words': ['esquivar-se', 'eximir-se', 'poupar-se', 'subtrair-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '322': {'words': ['aconfradar', 'aparceirar', 'emparceirar', 'irmanar'],
#   'category': 'Verbo',
#   'antonym': '1276'},
#  '323': {'words': ['abandear', 'aconfradar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '324': {'words': ['lembrar', 'recomendar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '325': {'words': ['ensinar', 'indicar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '326': {'words': ['acorrentar-se',
#    'algemar-se',
#    'atar-se',
#    'obrigar-se',
#    'prender-se',
#    'submeter-se',
#    'sujeitar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '327': {'words': ['afeiçoar', 'cativar', 'encadear'],
#   'category': 'Verbo',
#   'antonym': None},
#  '328': {'words': ['coordenar-se', 'encadear-se', 'ligar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '329': {'words': ['descarregar', 'desobstruir', 'libertar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '330': {'words': ['premiar'], 'category': 'Verbo', 'antonym': '2202'},
#  '331': {'words': ['acostar',
#    'aproximar',
#    'colar',
#    'coser',
#    'encostar',
#    'unir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '332': {'words': ['acostar', 'anexar', 'juntar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '333': {'words': ['cerrar', 'encostar', 'fechar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '334': {'words': ['abandonar', 'aposentar', 'encostar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '335': {'words': ['articular-se', 'associar-se', 'juntar-se', 'unir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '336': {'words': ['acotar', 'avaliar', 'calcular', 'cotar', 'estimar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '337': {'words': ['desabrigar', 'desacoitar', 'desagasalhar'],
#   'category': 'Verbo',
#   'antonym': '3006'},
#  '338': {'words': ['acovar',
#    'aterrar',
#    'cravar',
#    'encovar',
#    'enterrar',
#    'sepultar',
#    'soterrar',
#    'subterrar'],
#   'category': 'Verbo',
#   'antonym': '1375'},
#  '339': {'words': ['enterrar', 'isolar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '340': {'words': ['cravar-se', 'fixar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '341': {'words': ['afixar',
#    'firmar',
#    'fixar',
#    'pregar',
#    'prender',
#    'segurar'],
#   'category': 'Verbo',
#   'antonym': '1114'},
#  '342': {'words': ['aprazar', 'determinar', 'marcar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '343': {'words': ['apostolar', 'apostolizar', 'evangelizar', 'pregar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '344': {'words': ['preconizar', 'pregar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '345': {'words': ['acreditar', 'confiar', 'crer', 'fiar'],
#   'category': 'Verbo',
#   'antonym': '346'},
#  '346': {'words': ['desconfiar', 'descrer', 'duvidar'],
#   'category': 'Verbo',
#   'antonym': '345'},
#  '347': {'words': ['estirar', 'fiar', 'trefilar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '348': {'words': ['criminar-se', 'incriminar-se', 'inculpar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '349': {'words': ['acidificar', 'acrimoniar', 'azedar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '350': {'words': ['acendrar', 'acinzentar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '351': {'words': ['apurar', 'calcular', 'contar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '352': {'words': ['purificar', 'santificar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '353': {'words': ['exagerar-se', 'exceder-se', 'requintar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '354': {'words': ['acometer', 'afetar', 'contagiar', 'contaminar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '355': {'words': ['acudir', 'atender', 'obedecer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '356': {'words': ['divergir'], 'category': 'Verbo', 'antonym': '2743'},
#  '357': {'words': ['atender', 'deferir'],
#   'category': 'Verbo',
#   'antonym': '3547'},
#  '358': {'words': ['atender', 'despachar', 'servir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '359': {'words': ['condizer', 'responder'],
#   'category': 'Verbo',
#   'antonym': None},
#  '360': {'words': ['contrapor-se', 'opor-se', 'responder'],
#   'category': 'Verbo',
#   'antonym': None},
#  '361': {'words': ['defender'], 'category': 'Verbo', 'antonym': '238'},
#  '362': {'words': ['ameaçar', 'pairar'], 'category': 'Verbo', 'antonym': None},
#  '363': {'words': ['aflorar', 'pairar'], 'category': 'Verbo', 'antonym': None},
#  '364': {'words': ['enfezar-se', 'engrossar', 'irritar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '365': {'words': ['copiar', 'ler'], 'category': 'Verbo', 'antonym': None},
#  '366': {'words': ['carregar', 'pender', 'tender'],
#   'category': 'Verbo',
#   'antonym': None},
#  '367': {'words': ['aderir', 'ajustar-se', 'colar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '368': {'words': ['afetuar-se', 'grudar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '369': {'words': ['adiantar-se', 'avantajar-se', 'exceder-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '370': {'words': ['adiantar', 'compensar', 'resolver', 'servir', 'valer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '371': {'words': ['adiantar-se', 'antecipar-se', 'precipitar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '372': {'words': ['abonar-se', 'adinheirar-se', 'endinheirar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '373': {'words': ['adjetivar', 'qualificar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '374': {'words': ['chamar-se', 'classificar-se', 'qualificar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '375': {'words': ['conjurar', 'evocar', 'invocar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '376': {'words': ['adjutorar', 'assessorar', 'assistir', 'auxiliar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '377': {'words': ['administrar', 'aplicar', 'ministrar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '378': {'words': ['administrar', 'governar', 'reger'],
#   'category': 'Verbo',
#   'antonym': None},
#  '379': {'words': ['comandar', 'conduzir', 'dirigir', 'reger'],
#   'category': 'Verbo',
#   'antonym': None},
#  '380': {'words': ['reger', 'subordinar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '381': {'words': ['acionar', 'comandar', 'manipular', 'manobrar', 'operar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '382': {'words': ['adnumerar', 'enumerar', 'enunciar', 'numerar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '383': {'words': ['adnumerar', 'contar', 'enumerar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '384': {'words': ['contar', 'incluir', 'numerar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '385': {'words': ['adoecer', 'adoentar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '386': {'words': ['desadorar'], 'category': 'Verbo', 'antonym': '2596'},
#  '387': {'words': ['aduanar', 'alfandegar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '388': {'words': ['desmoronar-se',
#    'esbarrondar-se',
#    'esboroar-se',
#    'esfarelar-se',
#    'esfarinhar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '389': {'words': ['compor', 'constituir', 'formar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '390': {'words': ['diplomar', 'formar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '391': {'words': ['diplomar-se', 'formar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '392': {'words': ['deformar-se'], 'category': 'Verbo', 'antonym': '3863'},
#  '393': {'words': ['aferir', 'afilar'], 'category': 'Verbo', 'antonym': None},
#  '394': {'words': ['afermentar', 'fermentar', 'levedar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '395': {'words': ['aferrar', 'segurar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '396': {'words': ['aferrar', 'ancorar', 'aportar', 'atracar'],
#   'category': 'Verbo',
#   'antonym': '1113'},
#  '397': {'words': ['largar-se'], 'category': 'Verbo', 'antonym': '2896'},
#  '398': {'words': ['aportar', 'desembarcar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '399': {'words': ['cortar-se', 'ferir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '400': {'words': ['ferir', 'quebrar', 'romper'],
#   'category': 'Verbo',
#   'antonym': None},
#  '401': {'words': ['morder', 'picar'], 'category': 'Verbo', 'antonym': None},
#  '402': {'words': ['abonar-se', 'afiançar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '403': {'words': ['aflar', 'inspirar'],
#   'category': 'Verbo',
#   'antonym': '288'},
#  '404': {'words': ['bafejar', 'inspirar', 'transmitir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '405': {'words': ['assoprar', 'soprar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '406': {'words': ['afleumar', 'apachorrar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '407': {'words': ['afleumar-se', 'apachorrar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '408': {'words': ['cavar', 'revolver'], 'category': 'Verbo', 'antonym': None},
#  '409': {'words': ['revirar', 'revolver'],
#   'category': 'Verbo',
#   'antonym': None},
#  '410': {'words': ['girar', 'revolver'], 'category': 'Verbo', 'antonym': None},
#  '411': {'words': ['antegostar', 'antegozar', 'prelibar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '412': {'words': ['aliançar-se', 'aliar-se', 'casar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '413': {'words': ['esgoelar-se', 'goelar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '414': {'words': ['escravizar'], 'category': 'Verbo', 'antonym': '2931'},
#  '415': {'words': ['escravizar-se'], 'category': 'Verbo', 'antonym': '2642'},
#  '416': {'words': ['arrancar', 'puxar', 'sacar', 'tirar'],
#   'category': 'Verbo',
#   'antonym': '3933'},
#  '417': {'words': ['atrair', 'chamar', 'tirar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '418': {'words': ['descalçar', 'tirar'],
#   'category': 'Verbo',
#   'antonym': '798'},
#  '419': {'words': ['aproveitar', 'apurar', 'escolher', 'tirar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '420': {'words': ['desviar', 'tirar'], 'category': 'Verbo', 'antonym': None},
#  '421': {'words': ['reproduzir', 'retratar', 'tirar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '422': {'words': ['arrecadar', 'cobrar', 'pedir', 'tirar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '423': {'words': ['extrair', 'produzir', 'tirar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '424': {'words': ['excetuar-se', 'excluir-se', 'isentar-se'],
#   'category': 'Verbo',
#   'antonym': '2789'},
#  '425': {'words': ['afortunar-se', 'bem-aventurar-se', 'felicitar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '426': {'words': ['congratular', 'cumprimentar', 'felicitar', 'parabenizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '427': {'words': ['aplaudir-se',
#    'congratular-se',
#    'felicitar-se',
#    'gratular'],
#   'category': 'Verbo',
#   'antonym': None},
#  '428': {'words': ['aliviar', 'reanimar', 'refrescar', 'restaurar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '429': {'words': ['reforçar', 'refrescar', 'socorrer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '430': {'words': ['afretar', 'alugar', 'fretar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '431': {'words': ['abrasar', 'acender', 'atear'],
#   'category': 'Verbo',
#   'antonym': '2145'},
#  '432': {'words': ['alevantar-se', 'levantar-se'],
#   'category': 'Verbo',
#   'antonym': '3511'},
#  '433': {'words': ['agadanhar-se',
#    'agafanhar-se',
#    'agatanhar-se',
#    'arranhar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '434': {'words': ['agaiolar', 'engaiolar'],
#   'category': 'Verbo',
#   'antonym': '1332'},
#  '435': {'words': ['agarrar-se', 'apegar-se'],
#   'category': 'Verbo',
#   'antonym': '597'},
#  '436': {'words': ['alcançar', 'apanhar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '437': {'words': ['apanhar', 'caçar', 'pegar'],
#   'category': 'Verbo',
#   'antonym': '816'},
#  '438': {'words': ['apanhar', 'buscar', 'pegar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '439': {'words': ['abandidar-se', 'agatunar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '440': {'words': ['agenciar', 'contratar', 'recrutar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '441': {'words': ['agiotar', 'especular', 'rebater'],
#   'category': 'Verbo',
#   'antonym': None},
#  '442': {'words': ['agradar-se', 'enamorar-se', 'encantar-se', 'namorar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '443': {'words': ['cumprir-se', 'realizar-se', 'satisfazer-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '444': {'words': ['enquadrar-se', 'perfilar-se', 'quadrar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '445': {'words': ['desinteressar'], 'category': 'Verbo', 'antonym': '2701'},
#  '446': {'words': ['agradecer', 'gratificar', 'gratular'],
#   'category': 'Verbo',
#   'antonym': '1119'},
#  '447': {'words': ['agravar', 'sobrecarregar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '448': {'words': ['afetar-se', 'lesar-se', 'ofender-se', 'prejudicar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '449': {'words': ['ofender', 'pecar'], 'category': 'Verbo', 'antonym': None},
#  '450': {'words': ['agrumelar-se',
#    'agrumular-se',
#    'coagular-se',
#    'coalhar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '451': {'words': ['solidar-se', 'solidificar-se'],
#   'category': 'Verbo',
#   'antonym': '3312'},
#  '452': {'words': ['banhar', 'molhar'], 'category': 'Verbo', 'antonym': None},
#  '453': {'words': ['irrigar', 'regar'], 'category': 'Verbo', 'antonym': None},
#  '454': {'words': ['empanar', 'velar'], 'category': 'Verbo', 'antonym': None},
#  '455': {'words': ['agüentar-se', 'arranjar-se', 'haver-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '456': {'words': ['ajarretar', 'impossibilitar', 'jarretar'],
#   'category': 'Verbo',
#   'antonym': '1833'},
#  '457': {'words': ['castrar-se', 'mutilar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '458': {'words': ['ajaular', 'enjaular'],
#   'category': 'Verbo',
#   'antonym': None},
#  '459': {'words': ['ecarcerar-se',
#    'enclausurar-se',
#    'enjaular-se',
#    'prender-se',
#    'trancafiar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '460': {'words': ['ajoelhar', 'genuflectir', 'genufletir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '461': {'words': ['ajoelhar-se', 'genuflectir-se', 'genufletir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '462': {'words': ['amarrar', 'atar'], 'category': 'Verbo', 'antonym': '1252'},
#  '463': {'words': ['alagar', 'anaguar', 'inundar', 'submergir'],
#   'category': 'Verbo',
#   'antonym': '1125'},
#  '464': {'words': ['alagar-se', 'inundar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '465': {'words': ['banhar', 'inundar', 'molhar', 'umedecer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '466': {'words': ['alambrar', 'aramar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '467': {'words': ['alancear', 'lancear'],
#   'category': 'Verbo',
#   'antonym': None},
#  '468': {'words': ['adminicular', 'ministrar', 'propinar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '469': {'words': ['alargar-se',
#    'ampliar-se',
#    'aumentar-se',
#    'desenvolver-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '470': {'words': ['alargar-se', 'dilatar-se', 'distender-se', 'expandir-se'],
#   'category': 'Verbo',
#   'antonym': '957'},
#  '471': {'words': ['sobressaltar', 'transpor'],
#   'category': 'Verbo',
#   'antonym': None},
#  '472': {'words': ['acamar', 'deitar'], 'category': 'Verbo', 'antonym': None},
#  '473': {'words': ['alcalinar', 'alcalinizar', 'alcalizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '474': {'words': ['alcançar',
#    'chegar',
# ...
#   'category': 'Verbo',
#   'antonym': None},
#  '858': {'words': ['castelhanizar', 'espanholizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '859': {'words': ['cataplasmar', 'encataplasmar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '860': {'words': ['duvidar'], 'category': 'Verbo', 'antonym': '287'},
#  '861': {'words': ['causticar', 'queimar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '862': {'words': ['acautelar', 'cautelar', 'preservar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '863': {'words': ['acautelar', 'cautelar', 'evitar', 'premunir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '864': {'words': ['cavalar', 'cavaloar', 'escavaloar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '865': {'words': ['cavalear', 'cavalgar', 'cavaloar', 'encavalgar', 'galgar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '866': {'words': ['campear',
#    'cavalear',
#    'cavalgar',
#    'cavaloar',
#    'encavalgar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '867': {'words': ['ceifar', 'esfoiçar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '868': {'words': ['cem-dobrar', 'centuplicar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '869': {'words': ['censurar', 'proibir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '870': {'words': ['centralizar-se', 'centrar-se', 'concentrar-se'],
#   'category': 'Verbo',
#   'antonym': '1231'},
#  '871': {'words': ['centralizar', 'convergir', 'dirigir', 'tender'],
#   'category': 'Verbo',
#   'antonym': None},
#  '872': {'words': ['cercar', 'perseguir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '873': {'words': ['cercilhar', 'tonsurar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '874': {'words': ['cerrar-se', 'fechar-se', 'trancar-se'],
#   'category': 'Verbo',
#   'antonym': '1868'},
#  '875': {'words': ['continuar', 'persistir'],
#   'category': 'Verbo',
#   'antonym': '2488'},
#  '876': {'words': ['chacoalhar', 'chocalhar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '877': {'words': ['chagar-se', 'ulcerar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '878': {'words': ['atrair', 'chamar', 'puxar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '879': {'words': ['chamear', 'chamejar', 'flamar', 'flambar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '880': {'words': ['chantar-se',
#    'estabelecer-se',
#    'fixar-se',
#    'plantar-se',
#    'sentar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '881': {'words': ['chapar', 'chapear', 'laminar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '882': {'words': ['atrancar', 'chavear', 'fechar', 'trancar'],
#   'category': 'Verbo',
#   'antonym': '1408'},
#  '883': {'words': ['recender'], 'category': 'Verbo', 'antonym': '1145'},
#  '884': {'words': ['auferir', 'chincar', 'colher', 'lucrar', 'tirar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '885': {'words': ['enfaixar', 'envolver', 'faixar'],
#   'category': 'Verbo',
#   'antonym': '886'},
#  '886': {'words': ['desenfaixar'], 'category': 'Verbo', 'antonym': '885'},
#  '887': {'words': ['choferar', 'choferear'],
#   'category': 'Verbo',
#   'antonym': None},
#  '888': {'words': ['caramunhar', 'choramigar', 'choramingar', 'chorincar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '889': {'words': ['catucar', 'chuchar', 'cutucar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '890': {'words': ['chuchurrear', 'gorgolejar', 'grogolejar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '891': {'words': ['absorver', 'chupar', 'sorver', 'tragar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '892': {'words': ['chusmar', 'equipar', 'tripular'],
#   'category': 'Verbo',
#   'antonym': None},
#  '893': {'words': ['chincar', 'cincar', 'falhar', 'mentir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '894': {'words': ['enganar-se', 'equivocar-se', 'errar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '895': {'words': ['cinematizar', 'cinemizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '896': {'words': ['ligar', 'telefonar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '897': {'words': ['cingir-se',
#    'encolher-se',
#    'estreitar-se',
#    'limitar-se',
#    'refrear-se',
#    'restringir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '898': {'words': ['circular', 'mexer-se', 'mover-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '899': {'words': ['circular', 'deslocar-se', 'locomover-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '900': {'words': ['ciumar', 'enciumar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '901': {'words': ['concitar', 'excitar', 'exortar', 'incitar', 'mover'],
#   'category': 'Verbo',
#   'antonym': None},
#  '902': {'words': ['clarificar-se', 'purificar-se', 'santificar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '903': {'words': ['clarinar', 'cucuritar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '904': {'words': ['aclimar',
#    'aclimatar',
#    'aclimatizar',
#    'acostumar',
#    'climatizar',
#    'habituar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '905': {'words': ['cobrar-se', 'pagar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '906': {'words': ['cochilar', 'dormitar', 'toscanejar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '907': {'words': ['codificar', 'codizar', 'criptografar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '908': {'words': ['coexistir', 'concorrer', 'conviver'],
#   'category': 'Verbo',
#   'antonym': None},
#  '909': {'words': ['coivarar', 'encoivarar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '910': {'words': ['acolchetar', 'colchetar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '911': {'words': ['coletar', 'impor', 'taxar', 'tributar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '912': {'words': ['coletar', 'colher', 'recolher'],
#   'category': 'Verbo',
#   'antonym': None},
#  '913': {'words': ['colgar', 'dependurar', 'pender', 'pendurar', 'suspender'],
#   'category': 'Verbo',
#   'antonym': '1506'},
#  '914': {'words': ['depender', 'dependurar', 'pender', 'pendurar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '915': {'words': ['dependurar', 'empenhar', 'empenhorar', 'pendurar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '916': {'words': ['alcançar', 'atingir', 'chegar', 'colher', 'tocar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '917': {'words': ['colonizar', 'invadir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '918': {'words': ['descrever', 'pintar', 'retratar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '919': {'words': ['branquear',
#    'branquejar',
#    'encanecer',
#    'grisalhar',
#    'pintar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '920': {'words': ['cinerar', 'comburir', 'combustar', 'incinerar', 'queimar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '921': {'words': ['abrasar-se',
#    'ardejar',
#    'arder',
#    'chamear',
#    'chamejar',
#    'comburir-se',
#    'combustar-se',
#    'queimar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '922': {'words': ['analisar', 'comentar', 'criticar', 'examinar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '923': {'words': ['boquear', 'boquejar', 'murmurar', 'roer'],
#   'category': 'Verbo',
#   'antonym': None},
#  '924': {'words': ['comer', 'deixar', 'omitir', 'suprimir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '925': {'words': ['calar-se', 'omitir-se'],
#   'category': 'Verbo',
#   'antonym': '2134'},
#  '926': {'words': ['cometer', 'fazer', 'perpetrar', 'praticar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '927': {'words': ['cometer', 'oferecer', 'propor'],
#   'category': 'Verbo',
#   'antonym': None},
#  '928': {'words': ['compactar', 'comprimir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '929': {'words': ['compadecer-se',
#    'compatibilizar-se',
#    'conformar-se',
#    'harmonizar-se'],
#   'category': 'Verbo',
#   'antonym': '3143'},
#  '930': {'words': ['compartimentar', 'compartir', 'segmentar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '931': {'words': ['espalhar-se', 'ramificar-se', 'repartir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '932': {'words': ['dividir-se',
#    'ramificar-se',
#    'repartir-se',
#    'subdividir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '933': {'words': ['cadenciar', 'compassar', 'ritmar'],
#   'category': 'Verbo',
#   'antonym': '1226'},
#  '934': {'words': ['compassar', 'espaçar', 'espacear', 'espacejar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '935': {'words': ['compelir', 'empurrar', 'empuxar', 'impelir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '936': {'words': ['compensar', 'substituir', 'suprir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '937': {'words': ['incorporar-se', 'ingressar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '938': {'words': ['comprometer', 'compromissar', 'deslustrar', 'envergonhar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '939': {'words': ['comprometer',
#    'compromissar',
#    'empenhar',
#    'empenhorar',
#    'obrigar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '940': {'words': ['conceitar', 'conceituar'],
#   'category': 'Verbo',
#   'antonym': '1228'},
#  '941': {'words': ['arengar', 'arenguear', 'concionar', 'discursar', 'falar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '942': {'words': ['bradar', 'clamar', 'conclamar', 'pregar', 'vociferar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '943': {'words': ['aclamar', 'conclamar', 'coroar', 'eleger', 'proclamar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '944': {'words': ['concretizar-se',
#    'efetivar-se',
#    'materializar-se',
#    'realizar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '945': {'words': ['apezinhar', 'conculcar', 'espezinhar', 'pisar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '946': {'words': ['desensoberbecer-se', 'desinchar-se'],
#   'category': 'Verbo',
#   'antonym': '3732'},
#  '947': {'words': ['dilatar-se', 'expandir-se', 'rarefazer-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '948': {'words': ['adaptar', 'condicionar', 'preparar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '949': {'words': ['confeccionar', 'manipular', 'preparar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '950': {'words': ['caracterizar', 'caraterizar', 'retratar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '951': {'words': ['circunscrever',
#    'coarctar',
#    'confinar',
#    'delimitar',
#    'limitar',
#    'restringir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '952': {'words': ['afirmar', 'confirmar', 'manter', 'sustentar'],
#   'category': 'Verbo',
#   'antonym': '2778'},
#  '953': {'words': ['conflagrar', 'convulsionar', 'revolucionar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '954': {'words': ['agitar-se',
#    'alvoroçar-se',
#    'alvorotar-se',
#    'inquietar-se',
#    'mover-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '955': {'words': ['colidir', 'conflitar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '956': {'words': ['conformar-se',
#    'consolar-se',
#    'encolher-se',
#    'resignar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '957': {'words': ['comprimir-se',
#    'confranger-se',
#    'contorcer-se',
#    'contrair-se',
#    'encolher-se',
#    'retrair-se'],
#   'category': 'Verbo',
#   'antonym': '470'},
#  '958': {'words': ['congeminar', 'dobrar', 'multiplicar', 'redobrar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '959': {'words': ['congeminar-se',
#    'dobrar-se',
#    'multiplicar-se',
#    'redobrar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '960': {'words': ['confraternar',
#    'confraternizar',
#    'congeminar',
#    'fraternizar',
#    'irmanar'],
#   'category': 'Verbo',
#   'antonym': '1422'},
#  '961': {'words': ['cifrar-se', 'conglobar-se', 'reduzir-se', 'resumir-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '962': {'words': ['adunar',
#    'agregar',
#    'ajuntar',
#    'coadunar',
#    'conglobar',
#    'conglomerar',
#    'congregar',
#    'juntar',
#    'reunir'],
#   'category': 'Verbo',
#   'antonym': '1602'},
#  '963': {'words': ['congonhar', 'matear'],
#   'category': 'Verbo',
#   'antonym': None},
#  '964': {'words': ['chamar', 'congregar', 'convidar', 'convocar', 'invitar'],
#   'category': 'Verbo',
#   'antonym': '1247'},
#  '965': {'words': ['convidar', 'instar', 'solicitar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '966': {'words': ['convidar-se', 'oferecer-se', 'prestar-se', 'propor-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '967': {'words': ['aceitar',
#    'admitir',
#    'adotar',
#    'conhecer',
#    'receber',
#    'reconhecer',
#    'tomar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '968': {'words': ['conhecer', 'saber'],
#   'category': 'Verbo',
#   'antonym': '1235'},
#  '969': {'words': ['compreender',
#    'conceber',
#    'entender',
#    'perceber',
#    'reconhecer',
#    'saber',
#    'ver'],
#   'category': 'Verbo',
#   'antonym': '1374'},
#  '970': {'words': ['aproximar-se',
#    'conjugar-se',
#    'ligar-se',
#    'relacionar-se',
#    'tocar-se',
#    'unir-se'],
#   'category': 'Verbo',
#   'antonym': '2078'},
#  '971': {'words': ['beatificar',
#    'canonizar',
#    'glorificar',
#    'sagrar',
#    'santificar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '972': {'words': ['alertar', 'conscientizar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '973': {'words': ['proibir'], 'category': 'Verbo', 'antonym': '263'},
#  '974': {'words': ['conservar', 'preservar', 'proteger'],
#   'category': 'Verbo',
#   'antonym': None},
#  '975': {'words': ['conservar-se', 'durar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '976': {'words': ['consignar', 'encomendar', 'recomendar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '977': {'words': ['aconsoantar', 'consoar', 'rimar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '978': {'words': ['consolidar', 'solidar', 'solidificar'],
#   'category': 'Verbo',
#   'antonym': '3310'},
#  '979': {'words': ['arrepiar-se',
#    'consternar-se',
#    'espantar-se',
#    'estremecer-se',
#    'horripilar-se',
#    'horrorizar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '980': {'words': ['apertar', 'constranger'],
#   'category': 'Verbo',
#   'antonym': None},
#  '981': {'words': ['conceber', 'construir', 'criar', 'elaborar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '982': {'words': ['consolidar-se',
#    'consubstanciar-se',
#    'ligar-se',
#    'unificar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '983': {'words': ['aconselhar-se', 'consultar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '984': {'words': ['acabar-se',
#    'cerrar-se',
#    'concluir',
#    'consumar-se',
#    'encerrar-se',
#    'terminar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '985': {'words': ['contactar', 'contatar', 'tocar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '986': {'words': ['abarcar',
#    'abraçar',
#    'abranger',
#    'atingir',
#    'cingir',
#    'contemplar',
#    'conter'],
#   'category': 'Verbo',
#   'antonym': None},
#  '987': {'words': ['abarcar', 'abraçar', 'abranger', 'cingir', 'conter'],
#   'category': 'Verbo',
#   'antonym': None},
#  '988': {'words': ['contextualizar', 'contextuar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '989': {'words': ['contrair', 'fundir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '990': {'words': ['acudir',
#    'contravir',
#    'redargüir',
#    'responder',
#    'retorquir',
#    'retorqüir'],
#   'category': 'Verbo',
#   'antonym': None},
#  '991': {'words': ['controverter', 'discutir', 'questionar', 'rebater'],
#   'category': 'Verbo',
#   'antonym': None},
#  '992': {'words': ['comutar', 'converter', 'mudar', 'substituir', 'trocar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '993': {'words': ['convulsar', 'convulsionar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '994': {'words': ['conectar-se', 'coordenar-se', 'interligar-se', 'ligar-se'],
#   'category': 'Verbo',
#   'antonym': None},
#  '995': {'words': ['aferrar', 'arpar', 'arpear', 'arpoar', 'copejar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '996': {'words': ['copiar', 'imitar', 'plagiar', 'roubar'],
#   'category': 'Verbo',
#   'antonym': None},
#  '997': {'words': ['adeusar',
#    'apoteosar',
#    'apoteotizar',
#    'deificar',
#    'divinizar',
#    'endeusar'],
#   'category': 'Verbo',
#   'antonym': '1322'},
#  '998': {'words': ['corporalizar'], 'category': 'Verbo', 'antonym': None},
#  '999': {'words': ['corporalizar-se'], 'category': 'Verbo', 'antonym': None},
#  '1000': {'words': ['corporalizar-se',
#    'corporificar-se',
#    'incorporar-se',
#    'materializar-se'],
#   'category': 'Verbo',
#   'antonym': '1249'},
#  ...}
