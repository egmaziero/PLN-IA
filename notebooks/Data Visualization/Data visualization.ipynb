# %% [markdown]
# # Pandas
# ## Series
# One dimensional data structure
# ## Dataframe
# Two or more dimensional data structure: often a table with columns and rows

# %%
# %matplotlib inline

import matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# https://data.world/datafiniti/hotel-reviews

# %%
df = pd.read_csv('data/hotel_reviews.csv')

# %%
#df.head(5)
df.sample(2)
#df.tail()
# Out:
#                               address  \
# 3844  Bia Route 7 Garcia Trading Post
# 1605               611 State Route 20
#
#                                              categories      city country  \
# 3844                                             Hotels    Chinle      US
# 1605  Hotels,Hotel,Lodging,Bed & Breakfast & Inns,Mo...  Winthrop      US
#
#        latitude   longitude                          name postalCode  \
# 3844  36.151195 -109.547157  Holiday Inn Canyon De Chelly      86503
# 1605  48.470364 -120.176810                Mt Gardner Inn      98862
#
#                 province          reviews.date     reviews.dateAdded  \
# 3844  Cottonwood Station  2016-04-09T00:00:00Z  2016-10-19T04:00:51Z
# 1605                  WA  2016-01-14T00:00:00Z  2016-04-21T08:31:50Z
#
#       reviews.doRecommend  reviews.id  reviews.rating  \
# 3844                  NaN         NaN             4.0
# 1605                  NaN         NaN             5.0
#
#                                            reviews.text  \
# 3844  I stay at this hotel when visiting the nearby ...
# 1605  We felt so at home in room 4. Relaxing on a co...
#
#                                        reviews.title reviews.userCity  \
# 3844  The best hotel the town of Chinle has to offer              NaN
# 1605                         Perfect 4days/3 nights!          Clinton
#
#      reviews.username reviews.userProvince
# 3844       A Traveler                  NaN
# 1605           Raineo                   WA

# %%
df[df.city == 'Atlanta'].sample(2)
# Out:
#                 address                                         categories  \
# 1922  2920 Clairmont Rd  Hotels & Motels,Family-Friendly Hotels,Tourist...
# 1921  2920 Clairmont Rd  Hotels & Motels,Family-Friendly Hotels,Tourist...
#
#          city country   latitude  longitude  \
# 1922  Atlanta      US  33.843213 -84.314667
# 1921  Atlanta      US  33.843213 -84.314667
#
#                                                  name postalCode    province  \
# 1922  Holiday Inn Express Atlanta Ne - I-85 Clairmont      30329  Briarcliff
# 1921  Holiday Inn Express Atlanta Ne - I-85 Clairmont      30329  Briarcliff
#
#               reviews.date     reviews.dateAdded  reviews.doRecommend  \
# 1922  2012-06-23T05:00:00Z  2016-11-17T20:38:28Z                  NaN
# 1921  2012-06-23T05:00:00Z  2016-11-17T20:38:28Z                  NaN
#
#       reviews.id  reviews.rating  \
# 1922         NaN             NaN
# 1921         NaN             NaN
#
#                                            reviews.text reviews.title  \
# 1922  Make your travel more rewarding! Earn at least...           NaN
# 1921  Staff is very friendly, especially Mr. James t...           NaN
#
#      reviews.userCity     reviews.username reviews.userProvince
# 1922              NaN  Holiday Inn Express                  NaN
# 1921              NaN      Angela Le Grand                  NaN

# %%
df.city.describe()
# Out:
# count           5000
# unique           163
# top       Waterville
# freq             335
# Name: city, dtype: object

# %%
plt.figure(figsize=(20,10))
df['city'].sample(100).value_counts().plot(kind='pie',title='Cities')
plt.show()

# %%
def preprocessing(text):
    return text.lower()

df['city'].apply(preprocessing)
# Out:
# 0         mableton
# 1         mableton
# 2         mableton
# 3         mableton
# 4         mableton
# 5         mableton
# 6         mableton
# 7         mableton
# 8         mableton
# 9         mableton
# 10        mableton
# 11        mableton
# 12        mableton
# 13        mableton
# 14        mableton
# 15        mableton
# 16        mableton
# 17        mableton
# 18        mableton
# 19        mableton
# 20        mableton
# 21        mableton
# 22        mableton
# 23        mableton
# 24        mableton
# 25        mableton
# 26        mableton
# 27        mableton
# 28        mableton
# 29        mableton
#            ...
# 4970    alexandria
# 4971    alexandria
# 4972    alexandria
# 4973    alexandria
# 4974    alexandria
# 4975    alexandria
# 4976    alexandria
# 4977    alexandria
# 4978    alexandria
# 4979    alexandria
# 4980    alexandria
# 4981    alexandria
# 4982    alexandria
# 4983    alexandria
# 4984    alexandria
# 4985    alexandria
# 4986    alexandria
# 4987    alexandria
# 4988    alexandria
# 4989    alexandria
# 4990    alexandria
# 4991    alexandria
# 4992    alexandria
# 4993    alexandria
# 4994    alexandria
# 4995    alexandria
# 4996    alexandria
# 4997    alexandria
# 4998    alexandria
# 4999    alexandria
# Name: city, Length: 5000, dtype: object

# %%
your_data = {'A': [1,2,3,4,5], 'B': [5,4,3,2,1]}

df2 = pd.DataFrame(your_data)

df2
# Out:
#    A  B
# 0  1  5
# 1  2  4
# 2  3  3
# 3  4  2
# 4  5  1

# %%
import numpy as np
data = np.random.rand(10, 4)
data
# Out:
# array([[0.34734524, 0.86703326, 0.4915543 , 0.87047016],
#        [0.28659117, 0.08518401, 0.40939539, 0.51166461],
#        [0.36696402, 0.39066007, 0.60377276, 0.77361312],
#        [0.57298901, 0.17873035, 0.39973553, 0.62963434],
#        [0.34536542, 0.68974984, 0.93988662, 0.30729411],
#        [0.31216231, 0.04354917, 0.46077998, 0.74982333],
#        [0.35189954, 0.67604394, 0.22289782, 0.64854261],
#        [0.86061194, 0.22444673, 0.87721958, 0.22844952],
#        [0.38259659, 0.11060695, 0.65145168, 0.19142935],
#        [0.85786409, 0.03814197, 0.01124353, 0.56226493]])

# %%
df3 = pd.DataFrame(data, columns=['a', 'b', 'c', 'd'])
df3.plot.area();

# %%
df3.plot.scatter(x='a', y='b', s=df3['c'] * 200);

# %%
df3.plot.hexbin(x='a', y='b', gridsize=15)

# %% [markdown]
# # See more
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
